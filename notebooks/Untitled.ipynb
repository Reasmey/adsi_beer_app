# %%
import numpy as np
import pandas as pd

# %%
# import load_data function from 
# %load_ext autoreload
# %autoreload 2

# fix system path
import sys
sys.path.append("/home/jovyan/work")

# %%
# read in dataset and unzip
df_sample = pd.read_csv('../data/interim/df_sample.csv')

# %%
df_sample
# Out:
#    Unnamed: 0             brewery_name  review_aroma  review_appearance  \
# 0           0          Vecchio Birraio           2.0                2.5
# 1           1          Vecchio Birraio           2.5                3.0
# 2           2          Vecchio Birraio           2.5                3.0
# 3           3          Vecchio Birraio           3.0                3.5
# 4           4  Caldera Brewing Company           4.5                4.0
# 5           5  Caldera Brewing Company           3.5                3.5
# 6           6  Caldera Brewing Company           3.5                3.5
# 7           7  Caldera Brewing Company           2.5                3.5
# 8           8  Caldera Brewing Company           3.0                3.5
# 9           9  Caldera Brewing Company           3.5                5.0
#
#                        beer_style  review_palate  review_taste
# 0                      Hefeweizen            1.5           1.5
# ...

# %%
df_sample.drop('Unnamed: 0', axis=1,inplace=True)

# %%
df_sample
# Out:
#               brewery_name  review_aroma  review_appearance  \
# 0          Vecchio Birraio           2.0                2.5
# 1          Vecchio Birraio           2.5                3.0
# 2          Vecchio Birraio           2.5                3.0
# 3          Vecchio Birraio           3.0                3.5
# 4  Caldera Brewing Company           4.5                4.0
# 5  Caldera Brewing Company           3.5                3.5
# 6  Caldera Brewing Company           3.5                3.5
# 7  Caldera Brewing Company           2.5                3.5
# 8  Caldera Brewing Company           3.0                3.5
# 9  Caldera Brewing Company           3.5                5.0
#
#                        beer_style  review_palate  review_taste
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# ...

# %% [markdown]
# If the data was to be input as a dataframe, we need a function to convert to dataframe

# %%
def format_features(brewery_name: str, review_aroma: int, review_appearance: int, review_palate: int, review_taste: int):
      
        return {
        'Brewery Name': [brewery_name],
        'Aroma Score': [review_aroma],
        'Appearance Score': [review_appearance],
        'Palate Score': [review_palate],
        'Taste Score': [review_taste]
    }
